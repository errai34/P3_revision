# %% [markdown]
# # Small code to split the original data into training and testing sets

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

np.random.seed(1234)

# %%
data = pd.read_csv('AllOriginal.csv')
print("Length of data before dropping NaN: ", len(data))
data = data.dropna()
print("Length of data after dropping NaN: ", len(data))
# Out:
# Length of data before dropping NaN:  2915
# Length of data after dropping NaN:  2914

# %%
data.head()
# Out:
#             APOGEE_ID            source_id      LOGG         TEFF   ALPHA_M  \
# 0  2M18401969+4348380  2117126509915136384  2.850431  4717.869141  0.006766
# 1  2M18405556+4353012  2117149874537225344  2.666193  4934.826660  0.031347
# 2  2M18405585+4347083  2117125719641154176  1.974428  4288.254883  0.155339
# 3  2M18410298+4315506  2116830779945635200  2.723577  5079.484863 -0.014675
# 4  2M18413176+4358551  2116969387130311040  3.197070  4814.103027  0.016775
#
#         M_H      C_FE      N_FE          G         BP  ...  age_68l   ageErr  \
# 0  0.114532 -0.114552  0.280048  11.759661  12.351526  ...   7.4233  2.36755
# 1 -0.119351 -0.041083  0.182314  12.687871  13.218032  ...   3.0416  0.95585
# 2 -0.143906  0.103216  0.231846  11.615166  12.315401  ...  11.0918  7.50935
# 3  0.021505 -0.213453  0.465467  11.455835  11.956243  ...   0.4732  0.05460
# 4  0.227406 -0.004044  0.419772  12.796389  13.367275  ...   5.9566  1.71035
#
#      logAge  logAgeErr   distKpc  distKpc_68u  distKpc_68l  distErrKpc  \
# 0  0.972864   0.107140  0.983995     1.001127     0.967654    0.016736
# 1  0.584987   0.105896  1.734324     1.763933     1.706121    0.028906
# 2  1.214645   0.185907  1.674551     1.731497     1.623678    0.053910
# 3 -0.299210   0.045088  1.641782     1.654921     1.627421    0.013750
# 4  0.870521   0.098540  1.163756     1.181652     1.145460    0.018096
#
#    logDistKpc  logDistKpcErr
# 0   -0.007007       0.007384
# 1    0.239130       0.007236
# 2    0.223898       0.013961
# 3    0.215315       0.003639
# 4    0.065862       0.006755
#
# [5 rows x 38 columns]

# %%
data_train, data_test = train_test_split(data, test_size = 0.20, random_state = 42)

# %%
data_train.head()
# Out:
#                APOGEE_ID            source_id      LOGG         TEFF  \
# 1867  2M19371027+3833366  2052170902004055424  2.595899  4859.090820
# 2163  2M19424586+4744370  2080647604626475776  2.966436  4704.287109
# 2535  2M19492609+4352210  2078861001311174272  2.585862  4988.357422
# 897   2M19155325+4749366  2130919470971121536  2.770921  4813.821289
# 1259  2M19241817+4858463  2129549685640392192  2.577012  4542.238281
#
#        ALPHA_M       M_H      C_FE      N_FE          G         BP  ...  \
# 1867 -0.022834  0.171807 -0.167251  0.412339  11.764113  12.396488  ...
# 2163 -0.002465  0.367972 -0.028808  0.403981  12.895377  13.510695  ...
# 2535  0.010741 -0.025190 -0.238046  0.409674  11.281590  11.864048  ...
# 897   0.026832 -0.273174 -0.107823  0.244127  12.181296  12.715164  ...
# 1259  0.003721  0.217383  0.029497  0.337136  12.607643  13.256042  ...
#
#       age_68l   ageErr    logAge  logAgeErr   distKpc  distKpc_68u  \
# 1867   1.4760  0.10120  0.209676   0.027905  1.502098     1.515262
# 2163   7.3282  2.14160  0.965789   0.099944  1.364082     1.385117
# 2535   1.1537  0.05965  0.088915   0.021368  1.222420     1.232599
# 897    5.0165  1.60350  0.813154   0.107328  1.437957     1.461475
# 1259   7.5336  3.37555  1.023322   0.138934  1.751155     1.791000
#
#       distKpc_68l  distErrKpc  logDistKpc  logDistKpcErr
# 1867     1.490219    0.012522    0.176698       0.003619
# 2163     1.343136    0.020990    0.134841       0.006683
# 2535     1.211992    0.010303    0.087221       0.003661
# 897      1.414165    0.023655    0.157746       0.007146
# 1259     1.715931    0.037534    0.243324       0.009298
#
# [5 rows x 38 columns]

# %%
len(data_train)
# Out:
# 2331

# %%
len(data_test)
# Out:
# 583

# %%
data_train.to_csv('../train_data/TrainingOriginal.csv')
data_test.to_csv('../test_data/TestOriginal.csv')
